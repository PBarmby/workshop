# %%
# Notebook to align cube from different filters with each other using the SN3 filter as a reference. 
# Their is more emission line in SN3. Using it as a reference minimize the interpolation on the data.

# %%
# Import Libraries
from astropy.io import fits
import numpy as np
import pyfits
from astropy.utils.data import get_pkg_data_filename
from reproject import reproject_interp

# %%
# Define path and root name
path = '/h/r-nepton/M33_Dhruv/'
name = 'M33-SE'

# %%
# Reading files and removing Nans by spatial interpolations

# Flux, Heigt, velocity
ha, haheader = pyfits.getdata(path+name+'_SN3.1.0.ORCS/MAPS/'+name+'_SN3.1.0.LineMaps.map.6563.1x1.flux.fits', header=True)
nii1, nii1header = pyfits.getdata(path+name+'_SN3.1.0.ORCS/MAPS/'+name+'_SN3.1.0.LineMaps.map.6548.1x1.flux.fits', header=True)
nii2, nii2header = pyfits.getdata(path+name+'_SN3.1.0.ORCS/MAPS/'+name+'_SN3.1.0.LineMaps.map.6583.1x1.flux.fits', header=True)
sii1, sii1header = pyfits.getdata(path+name+'_SN3.1.0.ORCS/MAPS/'+name+'_SN3.1.0.LineMaps.map.6716.1x1.flux.fits', header=True)
sii2, sii2header = pyfits.getdata(path+name+'_SN3.1.0.ORCS/MAPS/'+name+'_SN3.1.0.LineMaps.map.6731.1x1.flux.fits', header=True)
cont3, cont3header = pyfits.getdata(path+name+'_SN3.1.0.ORCS/MAPS/'+name+'_SN3.1.0.LineMaps.map.all.1x1.height.fits', header=True)
v3, v3header = pyfits.getdata(path+name+'_SN3.1.0.ORCS/MAPS/'+name+'_SN3.1.0.LineMaps.map.6563.1x1.velocity.fits', header=True)

hb, hbheader = pyfits.getdata(path+name+'_SN2.1.0.ORCS/MAPS/'+name+'_SN2.1.0.LineMaps.map.4861.1x1.flux.fits', header=True)
oiii2, oiii2header = pyfits.getdata(path+name+'_SN2.1.0.ORCS/MAPS/'+name+'_SN2.1.0.LineMaps.map.4959.1x1.flux.fits', header=True)
oiii1, oiii1header = pyfits.getdata(path+name+'_SN2.1.0.ORCS/MAPS/'+name+'_SN2.1.0.LineMaps.map.5007.1x1.flux.fits', header=True)
cont2, cont2header = pyfits.getdata(path+name+'_SN2.1.0.ORCS/MAPS/'+name+'_SN2.1.0.LineMaps.map.all.1x1.height.fits', header=True)
v2, v2header = pyfits.getdata(path+name+'_SN2.1.0.ORCS/MAPS/'+name+'_SN2.1.0.LineMaps.map.4861.1x1.velocity.fits', header=True)

oii, oiiheader = pyfits.getdata(path+name+'_SN1.1.0.ORCS/MAPS/'+name+'_SN1.1.0.LineMaps.map.all.1x1.flux.fits', header=True)
cont1, cont1header = pyfits.getdata(path+name+'_SN1.1.0.ORCS/MAPS/'+name+'SN1.1.0.LineMaps.map.all.1x1.height.fits', header=True)
v1, v1header = pyfits.getdata(path+name+'_SN1.1.0.ORCS/MAPS/'+name+'SN1.1.0.LineMaps.map.all.1x1.velocity.fits', header=True)

# Flux, Heigt, velocity errors
haerr, haheadererr = pyfits.getdata(path+name+'_SN3.1.0.ORCS/MAPS/'+name+'_SN3.1.0.LineMaps.map.6563.1x1.flux.fits', header=True)
nii1err, nii1headererr = pyfits.getdata(path+name+'_SN3.1.0.ORCS/MAPS/'+name+'_SN3.1.0.LineMaps.map.6548.1x1.flux.fits', header=True)
nii2err, nii2headererr = pyfits.getdata(path+name+'_SN3.1.0.ORCS/MAPS/'+name+'_SN3.1.0.LineMaps.map.6583.1x1.flux.fits', header=True)
sii1err, sii1headererr = pyfits.getdata(path+name+'_SN3.1.0.ORCS/MAPS/'+name+'_SN3.1.0.LineMaps.map.6716.1x1.flux.fits', header=True)
sii2err, sii2headererr = pyfits.getdata(path+name+'_SN3.1.0.ORCS/MAPS/'+name+'_SN3.1.0.LineMaps.map.6731.1x1.flux.fits', header=True)
cont3err, cont3headererr = pyfits.getdata(path+name+'_SN3.1.0.ORCS/MAPS/'+name+'_SN3.1.0.LineMaps.map.all.1x1.height.fits', header=True)
v3err, v3headererr = pyfits.getdata(path+name+'_SN3.1.0.ORCS/MAPS/'+name+'_SN3.1.0.LineMaps.map.6563.1x1.velocity.fits', header=True)

hberr, hbheadererr = pyfits.getdata(path+name+'_SN2.1.0.ORCS/MAPS/'+name+'_SN2.1.0.LineMaps.map.4861.1x1.flux.fits', header=True)
oiii2err, oiii2headererr = pyfits.getdata(path+name+'_SN2.1.0.ORCS/MAPS/'+name+'_SN2.1.0.LineMaps.map.4959.1x1.flux.fits', header=True)
oiii1err, oiii1headererr = pyfits.getdata(path+name+'_SN2.1.0.ORCS/MAPS/'+name+'_SN2.1.0.LineMaps.map.5007.1x1.flux.fits', header=True)
cont2err, cont2headererr = pyfits.getdata(path+name+'_SN2.1.0.ORCS/MAPS/'+name+'_SN2.1.0.LineMaps.map.all.1x1.height.fits', header=True)
v2err, v2headererr = pyfits.getdata(path+name+'_SN2.1.0.ORCS/MAPS/'+name+'_SN2.1.0.LineMaps.map.4861.1x1.velocity.fits', header=True)

cont1err, cont1headererr = pyfits.getdata(path+name+'_SN1.1.0.ORCS/MAPS/'+name+'SN1.1.0.LineMaps.map.all.1x1.height.fits', header=True)
v1err, v1headererr = pyfits.getdata(path+name+'_SN1.1.0.ORCS/MAPS/'+name+'SN1.1.0.LineMaps.map.all.1x1.velocity.fits', header=True)

# Remove the contour lines bad values
ha[0:1,:] = 1e-22
ha[2062:2063,:] = 1e-22
ha[:,0:1] = 1e-22
ha[:,2046:2047] = 1e-22
hb[0:1,:] = 1e-22
hb[2062:2063,:] = 1e-22
hb[:,0:1] = 1e-22
hb[:,2046:2047] = 1e-22
nii1[0:1,:] = 1e-22
nii1[2062:2063,:] = 1e-22
nii1[:,0:1] = 1e-22
nii1[:,2046:2047] = 1e-22
nii2[0:1,:] = 1e-22
nii2[2062:2063,:] = 1e-22
nii2[:,0:1] = 1e-22
nii2[:,2046:2047] = 1e-22
sii1[0:1,:] = 1e-22
sii1[2062:2063,:] = 1e-22
sii1[:,0:1] = 1e-22
sii1[:,2046:2047] = 1e-22
sii2[0:1,:] = 1e-22
sii2[2062:2063,:] = 1e-22
sii2[:,0:1] = 1e-22
sii2[:,2046:2047] = 1e-22
oiii1[0:1,:] = 1e-22
oiii1[2062:2063,:] = 1e-22
oiii1[:,0:1] = 1e-22
oiii1[:,2046:2047] = 1e-22
oiii2[0:1,:] = 1e-22
oiii2[2062:2063,:] = 1e-22
oiii2[:,0:1] = 1e-22
oiii2[:,2046:2047] = 1e-22
oii[0:1,:] = 1e-22
oii[2062:2063,:] = 1e-22
oii[:,0:1] = 1e-22
oii[:,2046:2047] = 1e-22
cont1[0:1,:] = 1e-22
cont1[2062:2063,:] = 1e-22
cont1[:,0:1] = 1e-22
cont1[:,2046:2047] = 1e-22
cont2[0:1,:] = 1e-22
cont2[2062:2063,:] = 1e-22
cont2[:,0:1] = 1e-22
cont2[:,2046:2047] = 1e-22
cont3[0:1,:] = 1e-22
cont3[2062:2063,:] = 1e-22
cont3[:,0:1] = 1e-22
cont3[:,2046:2047] = 1e-22
cont1[(cont1 < 0)] = 0
cont2[(cont2 < 0)] = 0
cont3[(cont3 < 0)] = 0

haerr[0:1,:] = 1e-22
haerr[2062:2063,:] = 1e-22
haerr[:,0:1] = 1e-22
haerr[:,2046:2047] = 1e-22
hberr[0:1,:] = 1e-22
hberr[2062:2063,:] = 1e-22
hberr[:,0:1] = 1e-22
hberr[:,2046:2047] = 1e-22
nierri1[0:1,:] = 1e-22
nii1err[2062:2063,:] = 1e-22
nii1err[:,0:1] = 1e-22
nii1err[:,2046:2047] = 1e-22
nii2err[0:1,:] = 1e-22
nii2err[2062:2063,:] = 1e-22
nii2err[:,0:1] = 1e-22
nii2err[:,2046:2047] = 1e-22
sii1err[0:1,:] = 1e-22
sii1err[2062:2063,:] = 1e-22
sii1err[:,0:1] = 1e-22
sii1err[:,2046:2047] = 1e-22
sii2err[0:1,:] = 1e-22
sii2err[2062:2063,:] = 1e-22
sii2err[:,0:1] = 1e-22
sii2err[:,2046:2047] = 1e-22
oiii1err[0:1,:] = 1e-22
oiii1err[2062:2063,:] = 1e-22
oiii1err[:,0:1] = 1e-22
oiii1err[:,2046:2047] = 1e-22
oiii2err[0:1,:] = 1e-22
oiii2err[2062:2063,:] = 1e-22
oiii2err[:,0:1] = 1e-22
oiii2err[:,2046:2047] = 1e-22
oiierr[0:1,:] = 1e-22
oiierr[2062:2063,:] = 1e-22
oiierr[:,0:1] = 1e-22
oiierr[:,2046:2047] = 1e-22
cont1err[0:1,:] = 1e-22
cont1err[2062:2063,:] = 1e-22
cont1err[:,0:1] = 1e-22
cont1err[:,2046:2047] = 1e-22
cont2err[0:1,:] = 1e-22
cont2err[2062:2063,:] = 1e-22
cont2err[:,0:1] = 1e-22
cont2err[:,2046:2047] = 1e-22
cont3err[0:1,:] = 1e-22
cont3err[2062:2063,:] = 1e-22
cont3err[:,0:1] = 1e-22
cont3err[:,2046:2047] = 1e-22
cont1err[(cont1 < 0)] = 0
cont2err[(cont2 < 0)] = 0
cont3err[(cont3 < 0)] = 0

# Find the indices of the Nans pixels
indice_ha = np.where(np.isfinite(ha) == False)
indice_hb = np.where(np.isfinite(hb) == False)
indice_nii1 = np.where(np.isfinite(nii1) == False)
indice_nii2 = np.where(np.isfinite(nii2) == False)
indice_sii1 = np.where(np.isfinite(sii1) == False)
indice_sii2 = np.where(np.isfinite(sii2) == False)
indice_oiii1 = np.where(np.isfinite(oiii1) == False)
indice_oiii2 = np.where(np.isfinite(oiii2) == False)
indice_oii = np.where(np.isfinite(oii) == False)
indice_cont1 = np.where((np.isfinite(cont1) == False))
indice_cont2 = np.where((np.isfinite(cont2) == False))
indice_cont3 = np.where((np.isfinite(cont3) == False))
indice_v1 = np.where((np.isfinite(v1) == False))
indice_v2 = np.where((np.isfinite(v2) == False))
indice_v3 = np.where((np.isfinite(v3) == False))


indice_haerr = np.where(np.isfinite(haerr) == False)
indice_hberr = np.where(np.isfinite(hberr) == False)
indice_nii1err = np.where(np.isfinite(nii1err) == False)
indice_nii2err = np.where(np.isfinite(nii2err) == False)
indice_sii1err = np.where(np.isfinite(sii1err) == False)
indice_sii2err = np.where(np.isfinite(sii2err) == False)
indice_oiii1err = np.where(np.isfinite(oiii1err) == False)
indice_oiii2err = np.where(np.isfinite(oiii2err) == False)
indice_oiierr = np.where(np.isfinite(oiierr) == False)
indice_cont1err = np.where((np.isfinite(cont1err) == False))
indice_cont2err = np.where((np.isfinite(cont2err) == False))
indice_cont3err = np.where((np.isfinite(cont3err) == False))
indice_v1err = np.where((np.isfinite(v1err) == False))
indice_v2err = np.where((np.isfinite(v2err) == False))
indice_v3err = np.where((np.isfinite(v3err) == False))

# Mask the Nans with the mean of the surrounding [-2:+2]
for i in range(0,len(indice_ha[0])):  
    ha[indice_ha[0][i],indice_ha[1][i]] = np.nanmean(ha[(indice_ha[0][i]-2):(indice_ha[0][i]+2),(indice_ha[1][i]-2):(indice_ha[1][i]+2)])    

for i in range(0,len(indice_hb[0])):
    hb[indice_hb[0][i],indice_hb[1][i]] = np.nanmean(hb[(indice_hb[0][i]-2):(indice_hb[0][i]+2),(indice_hb[1][i]-2):(indice_hb[1][i]+2)])
 
for i in range(0,len(indice_nii1[0])):
    nii1[indice_nii1[0][i],indice_nii1[1][i]] = np.nanmean(nii1[(indice_nii1[0][i]-2):(indice_nii1[0][i]+2),(indice_nii1[1][i]-2):(indice_nii1[1][i]+2)])

for i in range(0,len(indice_nii2[0])):
    nii2[indice_nii2[0][i],indice_nii2[1][i]] = np.nanmean(nii2[(indice_nii2[0][i]-2):(indice_nii2[0][i]+2),(indice_nii2[1][i]-2):(indice_nii2[1][i]+2)])

for i in range(0,len(indice_sii1[0])):
    sii1[indice_sii1[0][i],indice_sii1[1][i]] = np.nanmean(sii1[(indice_sii1[0][i]-2):(indice_sii1[0][i]+2),(indice_sii1[1][i]-2):(indice_sii1[1][i]+2)])

for i in range(0,len(indice_sii2[0])):
    sii2[indice_sii2[0][i],indice_sii2[1][i]] = np.nanmean(sii2[(indice_sii2[0][i]-2):(indice_sii2[0][i]+2),(indice_sii2[1][i]-2):(indice_sii2[1][i]+2)])

for i in range(0,len(indice_oiii1[0])):
    oiii1[indice_oiii1[0][i],indice_oiii1[1][i]] = np.nanmean(oiii1[(indice_oiii1[0][i]-2):(indice_oiii1[0][i]+2),(indice_oiii1[1][i]-2):(indice_oiii1[1][i]+2)])

for i in range(0,len(indice_oiii2[0])):
    oiii2[indice_oiii2[0][i],indice_oiii2[1][i]] = np.nanmean(oiii2[(indice_oiii2[0][i]-2):(indice_oiii2[0][i]+2),(indice_oiii2[1][i]-2):(indice_oiii2[1][i]+2)])

for i in range(0,len(indice_oii[0])):
    oii[indice_oii[0][i],indice_oii[1][i]] = np.nanmean(oii[(indice_oii[0][i]-2):(indice_oii[0][i]+2),(indice_oii[1][i]-2):(indice_oii[1][i]+2)])

for i in range(0,len(indice_cont1[0])):
    cont1[indice_cont1[0][i],indice_cont1[1][i]] = np.nanmean(cont1[(indice_cont1[0][i]-2):(indice_cont1[0][i]+2),(indice_cont1[1][i]-2):(indice_cont1[1][i]+2)])

for i in range(0,len(indice_cont2[0])):
    cont2[indice_cont2[0][i],indice_cont2[1][i]] = np.nanmean(cont2[(indice_cont2[0][i]-2):(indice_cont2[0][i]+2),(indice_cont2[1][i]-2):(indice_cont2[1][i]+2)])

for i in range(0,len(indice_cont3[0])):
    cont3[indice_cont3[0][i],indice_cont3[1][i]] = np.nanmean(cont3[(indice_cont3[0][i]-2):(indice_cont3[0][i]+2),(indice_cont3[1][i]-2):(indice_cont3[1][i]+2)])

for i in range(0,len(indice_v1[0])):
    v1[indice_v1[0][i],indice_v1[1][i]] = np.nanmean(v1[(indice_v1[0][i]-2):(indice_v1[0][i]+2),(indice_v1[1][i]-2):(indice_v1[1][i]+2)])

for i in range(0,len(indice_v2[0])):
    v2[indice_v2[0][i],indice_v2[1][i]] = np.nanmean(v2[(indice_v2[0][i]-2):(indice_v2[0][i]+2),(indice_v2[1][i]-2):(indice_v2[1][i]+2)])

for i in range(0,len(indice_v3[0])):
    v3[indice_v3[0][i],indice_v3[1][i]] = np.nanmean(v3[(indice_v3[0][i]-2):(indice_v3[0][i]+2),(indice_v3[1][i]-2):(indice_v3[1][i]+2)])

# Write NoNans files
pyfits.writeto(path+'Analysis/'+name+'_SN3.1.0.LineMaps.map.6563.1x1.flux_nonans.fits', ha, header=haheader, clobber=True)
pyfits.writeto(path+'Analysis/'+name+'_SN3.1.0.LineMaps.map.6548.1x1.flux_nonans.fits', nii1, header=nii1header, clobber=True)
pyfits.writeto(path+'Analysis/'+name+'_SN3.1.0.LineMaps.map.6583.1x1.flux_nonans.fits', nii2, header=nii2header, clobber=True)
pyfits.writeto(path+'Analysis/'+name+'_SN3.1.0.LineMaps.map.6716.1x1.flux_nonans.fits', sii1, header=sii1header, clobber=True)
pyfits.writeto(path+'Analysis/'+name+'_SN3.1.0.LineMaps.map.6731.1x1.flux_nonans.fits', sii2, header=sii2header, clobber=True)
pyfits.writeto(path+'Analysis/'+name+'_SN2.1.0.LineMaps.map.4861.1x1.flux_nonans.fits', hb, header=hbheader, clobber=True)
pyfits.writeto(path+'Analysis/'+name+'_SN2.1.0.LineMaps.map.4959.1x1.flux_nonans.fits', oiii1, header=oiii1header, clobber=True)
pyfits.writeto(path+'Analysis/'+name+'_SN2.1.0.LineMaps.map.5007.1x1.flux_nonans.fits', oiii2, header=oiii2header, clobber=True)
pyfits.writeto(path+'Analysis/'+name+'_SN1.1.0.LineMaps.map.3727.1x1.flux_nonans.fits', oii, header=oiiheader, clobber=True)
pyfits.writeto(path+'Analysis/'+name+'_SN1.1.0.LineMaps.map.all.1x1.height_nonans.fits', cont1, header=cont1header, clobber=True)
pyfits.writeto(path+'Analysis/'+name+'_SN2.1.0.LineMaps.map.all.1x1.height_nonans.fits', cont2, header=cont2header, clobber=True)
pyfits.writeto(path+'Analysis/'+name+'_SN3.1.0.LineMaps.map.all.1x1.height_nonans.fits', cont3, header=cont3header, clobber=True)
pyfits.writeto(path+'Analysis/'+name+'_SN1.1.0.LineMaps.map.all.1x1.velocity_nonans.fits', v1, header=v1header, clobber=True)
pyfits.writeto(path+'Analysis/'+name+'_SN2.1.0.LineMaps.map.all.1x1.velocity_nonans.fits', v2, header=v2header, clobber=True)
pyfits.writeto(path+'Analysis/'+name+'_SN3.1.0.LineMaps.map.all.1x1.velocity_nonans.fits', v3, header=v3header, clobber=True)

# Propagate errors

for i in range(0,len(indice_ha[0])):  
    haerr[indice_haerr[0][i],indice_haerr[1][i]] = np.nanmean(haerr[(indice_haerr[0][i]-2):(indice_haerr[0][i]+2),(indice_haerr[1][i]-2):(indice_haerr[1][i]+2)])    

for i in range(0,len(indice_hb[0])):
    hberr[indice_hberr[0][i],indice_hberr[1][i]] = np.nanmean(hberr[(indice_hberr[0][i]-2):(indice_hberr[0][i]+2),(indice_hberr[1][i]-2):(indice_hberr[1][i]+2)])
 
for i in range(0,len(indice_nii1[0])):
    nii1err[indice_nii1err[0][i],indice_nii1err[1][i]] = np.nanmean(nii1err[(indice_nii1err[0][i]-2):(indice_nii1err[0][i]+2),(indice_nii1err[1][i]-2):(indice_nii1err[1][i]+2)])

for i in range(0,len(indice_nii2[0])):
    nii2err[indice_nii2err[0][i],indice_nii2err[1][i]] = np.nanmean(nii2err[(indice_nii2err[0][i]-2):(indice_nii2err[0][i]+2),(indice_nii2err[1][i]-2):(indice_nii2err[1][i]+2)])

for i in range(0,len(indice_sii1[0])):
    sii1err[indice_sii1err[0][i],indice_sii1err[1][i]] = np.nanmean(sii1err[(indice_sii1err[0][i]-2):(indice_sii1err[0][i]+2),(indice_sii1err[1][i]-2):(indice_sii1err[1][i]+2)])

for i in range(0,len(indice_sii2[0])):
    sii2err[indice_sii2err[0][i],indice_sii2err[1][i]] = np.nanmean(sii2err[(indice_sii2err[0][i]-2):(indice_sii2err[0][i]+2),(indice_sii2err[1][i]-2):(indice_sii2err[1][i]+2)])

for i in range(0,len(indice_oiii1[0])):
    oiii1err[indice_oiii1err[0][i],indice_oiii1err[1][i]] = np.nanmean(oiii1err[(indice_oiii1err[0][i]-2):(indice_oiii1err[0][i]+2),(indice_oiii1err[1][i]-2):(indice_oiii1err[1][i]+2)])

for i in range(0,len(indice_oiii2[0])):
    oiii2err[indice_oiii2err[0][i],indice_oiii2err[1][i]] = np.nanmean(oiii2err[(indice_oiii2err[0][i]-2):(indice_oiii2err[0][i]+2),(indice_oiii2err[1][i]-2):(indice_oiii2err[1][i]+2)])

for i in range(0,len(indice_oii[0])):
    oiierr[indice_oiierr[0][i],indice_oiierr[1][i]] = np.nanmean(oiierr[(indice_oiierr[0][i]-2):(indice_oiierr[0][i]+2),(indice_oiierr[1][i]-2):(indice_oiierr[1][i]+2)])

for i in range(0,len(indice_cont1[0])):
    cont1err[indice_cont1err[0][i],indice_cont1err[1][i]] = np.nanmean(cont1err[(indice_cont1err[0][i]-2):(indice_cont1err[0][i]+2),(indice_cont1err[1][i]-2):(indice_cont1err[1][i]+2)])

for i in range(0,len(indice_cont2[0])):
    cont2err[indice_cont2err[0][i],indice_cont2err[1][i]] = np.nanmean(cont2err[(indice_cont2err[0][i]-2):(indice_cont2err[0][i]+2),(indice_cont2err[1][i]-2):(indice_cont2err[1][i]+2)])

for i in range(0,len(indice_cont3[0])):
    cont3err[indice_cont3err[0][i],indice_cont3err[1][i]] = np.nanmean(cont3err[(indice_cont3err[0][i]-2):(indice_cont3err[0][i]+2),(indice_cont3err[1][i]-2):(indice_cont3err[1][i]+2)])

for i in range(0,len(indice_v1[0])):
    v1err[indice_v1err[0][i],indice_v1err[1][i]] = np.nanmean(v1err[(indice_v1err[0][i]-2):(indice_v1err[0][i]+2),(indice_v1err[1][i]-2):(indice_v1err[1][i]+2)])

for i in range(0,len(indice_v2[0])):
    v2err[indice_v2err[0][i],indice_v2err[1][i]] = np.nanmean(v2err[(indice_v2err[0][i]-2):(indice_v2err[0][i]+2),(indice_v2err[1][i]-2):(indice_v2err[1][i]+2)])

for i in range(0,len(indice_v3[0])):
    v3err[indice_v3err[0][i],indice_v3err[1][i]] = np.nanmean(v3err[(indice_v3err[0][i]-2):(indice_v3err[0][i]+2),(indice_v3err[1][i]-2):(indice_v3err[1][i]+2)])

# Write Nonans files errors
pyfits.writeto(path+'Analysis/No_nans/'+name+'_SN3.1.0.LineMaps.map.6563.1x1.flux_nonans.fits', ha, header=haheader, clobber=True)
pyfits.writeto(path+'Analysis/No_nans/'+name+'_SN3.1.0.LineMaps.map.6548.1x1.flux_nonans.fits', nii1, header=nii1header, clobber=True)
pyfits.writeto(path+'Analysis/No_nans/'+name+'_SN3.1.0.LineMaps.map.6583.1x1.flux_nonans.fits', nii2, header=nii2header, clobber=True)
pyfits.writeto(path+'Analysis/No_nans/'+name+'_SN3.1.0.LineMaps.map.6716.1x1.flux_nonans.fits', sii1, header=sii1header, clobber=True)
pyfits.writeto(path+'Analysis/No_nans/'+name+'_SN3.1.0.LineMaps.map.6731.1x1.flux_nonans.fits', sii2, header=sii2header, clobber=True)
pyfits.writeto(path+'Analysis/No_nans/'+name+'_SN2.1.0.LineMaps.map.4861.1x1.flux_nonans.fits', hb, header=hbheader, clobber=True)
pyfits.writeto(path+'Analysis/No_nans/'+name+'_SN2.1.0.LineMaps.map.4959.1x1.flux_nonans.fits', oiii1, header=oiii1header, clobber=True)
pyfits.writeto(path+'Analysis/No_nans/'+name+'_SN2.1.0.LineMaps.map.5007.1x1.flux_nonans.fits', oiii2, header=oiii2header, clobber=True)
pyfits.writeto(path+'Analysis/No_nans/'+name+'_SN1.1.0.LineMaps.map.3727.1x1.flux_nonans.fits', oii, header=oiiheader, clobber=True)
pyfits.writeto(path+'Analysis/No_nans/'+name+'_SN1.1.0.LineMaps.map.all.1x1.height_nonans.fits', cont1, header=cont1header, clobber=True)
pyfits.writeto(path+'Analysis/No_nans/'+name+'_SN2.1.0.LineMaps.map.all.1x1.height_nonans.fits', cont2, header=cont2header, clobber=True)
pyfits.writeto(path+'Analysis/No_nans/'+name+'_SN3.1.0.LineMaps.map.all.1x1.height_nonans.fits', cont3, header=cont3header, clobber=True)
pyfits.writeto(path+'Analysis/No_nans/'+name+'_SN1.1.0.LineMaps.map.all.1x1.velocity_nonans.fits', v1, header=v1header, clobber=True)
pyfits.writeto(path+'Analysis/No_nans/'+name+'_SN2.1.0.LineMaps.map.all.1x1.velocity_nonans.fits', v2, header=v2header, clobber=True)
pyfits.writeto(path+'Analysis/No_nans/'+name+'_SN3.1.0.LineMaps.map.all.1x1.velocity_nonans.fits', v3, header=v3header, clobber=True)

# Write Nonans files error
pyfits.writeto(path+'Analysis/No_nans/'+name+'_SN3.1.0.LineMaps.map.6563.1x1.flux-err_nonans.fits', haerr, header=haheadererr, clobber=True)
pyfits.writeto(path+'Analysis/No_nans/'+name+'_SN3.1.0.LineMaps.map.6548.1x1.flux-err_nonans.fits', nii1err, header=nii1headererr, clobber=True)
pyfits.writeto(path+'Analysis/No_nans/'+name+'_SN3.1.0.LineMaps.map.6583.1x1.flux-err_nonans.fits', nii2err, header=nii2headererr, clobber=True)
pyfits.writeto(path+'Analysis/No_nans/'+name+'_SN3.1.0.LineMaps.map.6716.1x1.flux-err_nonans.fits', sii1err, header=sii1headererr, clobber=True)
pyfits.writeto(path+'Analysis/No_nans/'+name+'_SN3.1.0.LineMaps.map.6731.1x1.flux-err_nonans.fits', sii2err, header=sii2headererr, clobber=True)
pyfits.writeto(path+'Analysis/No_nans/'+name+'_SN2.1.0.LineMaps.map.4861.1x1.flux-err_nonans.fits', hberr, header=hbheadererr, clobber=True)
pyfits.writeto(path+'Analysis/No_nans/'+name+'_SN2.1.0.LineMaps.map.4959.1x1.flux-err_nonans.fits', oiii1err, header=oiii1headererr, clobber=True)
pyfits.writeto(path+'Analysis/No_nans/'+name+'_SN2.1.0.LineMaps.map.5007.1x1.flux-err_nonans.fits', oiii2err, header=oiii2headererr, clobber=True)
pyfits.writeto(path+'Analysis/No_nans/'+name+'_SN1.1.0.LineMaps.map.3727.1x1.flux-err_nonans.fits', oiierr, header=oiiheadererr, clobber=True)
pyfits.writeto(path+'Analysis/No_nans/'+name+'_SN1.1.0.LineMaps.map.all.1x1.height-err_nonans.fits', cont1err, header=cont1headererr, clobber=True)
pyfits.writeto(path+'Analysis/No_nans/'+name+'_SN2.1.0.LineMaps.map.all.1x1.height-err_nonans.fits', cont2err, header=cont2headererr, clobber=True)
pyfits.writeto(path+'Analysis/No_nans/'+name+'_SN3.1.0.LineMaps.map.all.1x1.height-err_nonans.fits', cont3err, header=cont3headererr, clobber=True)
pyfits.writeto(path+'Analysis/No_nans/'+name+'_SN1.1.0.LineMaps.map.all.1x1.velocity-err_nonans.fits', v1err, header=v1headererr, clobber=True)
pyfits.writeto(path+'Analysis/No_nans/'+name+'_SN2.1.0.LineMaps.map.all.1x1.velocity-err_nonans.fits', v2err, header=v2headererr, clobber=True)
pyfits.writeto(path+'Analysis/No_nans/'+name+'_SN3.1.0.LineMaps.map.all.1x1.velocity-err_nonans.fits', v3err, header=v3headererr, clobber=True)
# Out:
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-3-98e86992c758> in <module>()
#       2
#       3 # Flux, Heigt, velocity
# ----> 4 ha, haheader = pyfits.getdata(path+name+'_SN3.1.0.ORCS/MAPS/'+name+'_SN3.1.0.LineMaps.map.6563.1x1.flux.fits', header=True)
#       5 nii1, nii1header = pyfits.getdata(path+name+'_SN3.1.0.ORCS/MAPS/'+name+'_SN3.1.0.LineMaps.map.6548.1x1.flux.fits', header=True)
#       6 nii2, nii2header = pyfits.getdata(path+name+'_SN3.1.0.ORCS/MAPS/'+name+'_SN3.1.0.LineMaps.map.6583.1x1.flux.fits', header=True)
#
# /usr/local/lib/python2.7/site-packages/pyfits/convenience.pyc in getdata(filename, *args, **kwargs)
#     178     view = kwargs.pop('view', None)
#     179
# --> 180     hdulist, extidx = _getext(filename, mode, *args, **kwargs)
#     181     hdu = hdulist[extidx]
#     182     data = hdu.data
#
# ...

# %%
# Write the aligned SN3 maps (No modifications but keep the roots of the file an _align for simplicity)
pyfits.writeto(path+'Analysis/Aligned/'+name+'_SN3.1.0.LineMaps.map.6563.1x1.flux_align.fits', ha, header=haheader, clobber=True)
pyfits.writeto(path+'Analysis/Aligned/'+name+'_SN3.1.0.LineMaps.map.6548.1x1.flux_align.fits', nii1, header=nii1header, clobber=True)
pyfits.writeto(path+'Analysis/Aligned/'+name+'_SN3.1.0.LineMaps.map.6583.1x1.flux_align.fits', nii2, header=nii2header, clobber=True)
pyfits.writeto(path+'Analysis/Aligned/'+name+'_SN3.1.0.LineMaps.map.6716.1x1.flux_align.fits', sii1, header=sii1header, clobber=True)
pyfits.writeto(path+'Analysis/Aligned/'+name+'_SN3.1.0.LineMaps.map.6731.1x1.flux_align.fits', sii2, header=sii2header, clobber=True)
pyfits.writeto(path+'Analysis/Aligned/'+name+'_SN3.1.0.LineMaps.map.all.1x1.height_align.fits', cont3, header=cont3header, clobber=True)
pyfits.writeto(path+'Analysis/Aligned/'+name+'_SN3.1.0.LineMaps.map.6563.1x1.velocity_align.fits', v3, header=v3header, clobber=True)

# Write the aligned SN3 maps error (No modifications but keep the roots of the file an _align for simplicity)

pyfits.writeto(path+'Analysis/Aligned/'+name+'_SN3.1.0.LineMaps.map.6563.1x1.flux-err_align.fits', ha-err, header=haheader-err, clobber=True)
pyfits.writeto(path+'Analysis/Aligned/'+name+'_SN3.1.0.LineMaps.map.6548.1x1.flux-err_align.fits', nii1-err, header=nii1header-err, clobber=True)
pyfits.writeto(path+'Analysis/Aligned/'+name+'_SN3.1.0.LineMaps.map.6583.1x1.flux-err_align.fits', nii2-err, header=nii2header-err, clobber=True)
pyfits.writeto(path+'Analysis/Aligned/'+name+'_SN3.1.0.LineMaps.map.6716.1x1.flux-err_align.fits', sii1-err, header=sii1header-err, clobber=True)
pyfits.writeto(path+'Analysis/Aligned/'+name+'_SN3.1.0.LineMaps.map.6731.1x1.flux-err_align.fits', sii2-err, header=sii2header-err, clobber=True)
pyfits.writeto(path+'Analysis/Aligned/'+name+'_SN3.1.0.LineMaps.map.all.1x1.height-err_align.fits', cont3-err, header=cont3header-err, clobber=True)
pyfits.writeto(path+'Analysis/Aligned/'+name+'_SN3.1.0.LineMaps.map.6563.1x1.velocity-err_align.fits', v3-err, header=v3header-err, clobber=True)
# Out:
# /usr/local/lib/python2.7/site-packages/pyfits/file.py:372: UserWarning: Overwriting existing file '/Users/Laurie/M33-SE_SN3.1.0.ORCS/MAPS/M33-SE_SN3.1.0.LineMaps.map.6563.1x1.flux_align.fits'.
#   warnings.warn("Overwriting existing file %r." % self.name)
# /usr/local/lib/python2.7/site-packages/pyfits/file.py:372: UserWarning: Overwriting existing file '/Users/Laurie/M33-SE_SN3.1.0.ORCS/MAPS/M33-SE_SN3.1.0.LineMaps.map.6548.1x1.flux_align.fits'.
#   warnings.warn("Overwriting existing file %r." % self.name)
# /usr/local/lib/python2.7/site-packages/pyfits/file.py:372: UserWarning: Overwriting existing file '/Users/Laurie/M33-SE_SN3.1.0.ORCS/MAPS/M33-SE_SN3.1.0.LineMaps.map.6583.1x1.flux_align.fits'.
#   warnings.warn("Overwriting existing file %r." % self.name)
# /usr/local/lib/python2.7/site-packages/pyfits/file.py:372: UserWarning: Overwriting existing file '/Users/Laurie/M33-SE_SN3.1.0.ORCS/MAPS/M33-SE_SN3.1.0.LineMaps.map.6716.1x1.flux_align.fits'.
# ...

# %%
## Align the fits files.

hdu1 = fits.open(get_pkg_data_filename(path+'Analysis/No_nans/'+name+'_SN3.1.0.LineMaps.map.6563.1x1.flux_nonans.fits'))[0]
hdu2 = fits.open(get_pkg_data_filename(path+'Analysis/No_nans/'+name+'_SN2.1.0.LineMaps.map.4861.1x1.flux_nonans.fits'))[0]
hdu9 = fits.open(get_pkg_data_filename(path+'Analysis/No_nans/'+name+'_SN2.1.0.LineMaps.map.4861.1x1.velocity_nonans.fits'))[0]
hdu3 = fits.open(get_pkg_data_filename(path+'Analysis/No_nans/'+name+'_SN2.1.0.LineMaps.map.4959.1x1.flux_nonans.fits'))[0]
hdu4 = fits.open(get_pkg_data_filename(path+'Analysis/No_nans/'+name+'_SN2.1.0.LineMaps.map.5007.1x1.flux_nonans.fits'))[0]
hdu5 = fits.open(get_pkg_data_filename(path+'Analysis/No_nans/'+name+'_SN1.1.0.LineMaps.map.3727.1x1.flux_nonans.fits'))[0]
hdu6 = fits.open(get_pkg_data_filename(path+'Analysis/No_nans/'+name+'_SN2.1.0.LineMaps.map.all.1x1.height_nonans.fits'))[0]
hdu7 = fits.open(get_pkg_data_filename(path+'Analysis/No_nans/'+name+'_SN1.1.0.LineMaps.map.3727.1x1.height_nonans.fits'))[0]
hdu8 = fits.open(get_pkg_data_filename(path+'Analysis/No_nans/'+name+'_SN1.1.0.LineMaps.map.3727.1x1.velocity_nonans.fits'))[0]

hdu22 = fits.open(get_pkg_data_filename(path+'Analysis/No_nans/'+name+'_SN2.1.0.LineMaps.map.4861.1x1.flux-err_nonans.fits'))[0]
hdu99 = fits.open(get_pkg_data_filename(path+'Analysis/No_nans/'+name+'_SN2.1.0.LineMaps.map.4861.1x1.velocityerr_nonans.fits'))[0]
hdu33 = fits.open(get_pkg_data_filename(path+'Analysis/No_nans/'+name+'_SN2.1.0.LineMaps.map.4959.1x1.fluxerr_nonans.fits'))[0]
hdu44 = fits.open(get_pkg_data_filename(path+'Analysis/No_nans/'+name+'_SN2.1.0.LineMaps.map.5007.1x1.fluxerr_nonans.fits'))[0]
hdu55 = fits.open(get_pkg_data_filename(path+'Analysis/No_nans/'+name+'_SN1.1.0.LineMaps.map.3727.1x1.fluxerr_nonans.fits'))[0]
hdu66 = fits.open(get_pkg_data_filename(path+'Analysis/No_nans/'+name+'_SN2.1.0.LineMaps.map.all.1x1.heighterr_nonans.fits'))[0]
hdu77 = fits.open(get_pkg_data_filename(path+'Analysis/No_nans/'+name+'_SN1.1.0.LineMaps.map.3727.1x1.heighterr_nonans.fits'))[0]
hdu88 = fits.open(get_pkg_data_filename(path+'Analysis/No_nans/'+name+'_SN1.1.0.LineMaps.map.3727.1x1.velocityerr_nonans.fits'))[0]

# %%
# Calculate the reprojection

array2, footprint2 = reproject_interp(hdu2, hdu1.header, hdu_in=1)
array3, footprint3 = reproject_interp(hdu3, hdu1.header, hdu_in=1)
array4, footprint4 = reproject_interp(hdu4, hdu1.header, hdu_in=1)
array5, footprint5 = reproject_interp(hdu5, hdu1.header, hdu_in=1)
array6, footprint6 = reproject_interp(hdu6, hdu1.header, hdu_in=1)
array7, footprint7 = reproject_interp(hdu7, hdu1.header, hdu_in=1)
array8, footprint8 = reproject_interp(hdu8, hdu1.header, hdu_in=1)
array9, footprint9 = reproject_interp(hdu9, hdu1.header, hdu_in=1)

array22, footprint22 = reproject_interp(hdu22, hdu1.header, hdu_in=1)
array33, footprint33 = reproject_interp(hdu33, hdu1.header, hdu_in=1)
array44, footprint44 = reproject_interp(hdu44, hdu1.header, hdu_in=1)
array55, footprint55 = reproject_interp(hdu55, hdu1.header, hdu_in=1)
array66, footprint66 = reproject_interp(hdu66, hdu1.header, hdu_in=1)
array77, footprint77 = reproject_interp(hdu77, hdu1.header, hdu_in=1)
array88, footprint88 = reproject_interp(hdu88, hdu1.header, hdu_in=1)
array99, footprint99 = reproject_interp(hdu99, hdu1.header, hdu_in=1)
# Out:
# INFO:
#                 Inconsistent SIP distortion information is present in the FITS header and the WCS object:
#                 SIP coefficients were detected, but CTYPE is missing a "-SIP" suffix.
#                 astropy.wcs is using the SIP distortion coefficients,
#                 therefore the coordinates calculated here might be incorrect.
#
#                 If you do not want to apply the SIP distortion coefficients,
#                 please remove the SIP coefficients from the FITS header or the
#                 WCS object.  As an example, if the image is already distortion-corrected
#                 (e.g., drizzled) then distortion components should not apply and the SIP
#                 coefficients should be removed.
#
#                 While the SIP distortion coefficients are being applied here, if that was indeed the intent,
#                 for consistency please append "-SIP" to the CTYPE in the FITS header or the WCS object.
#
# ...

# %%
# Write aligned maps

fits.writeto(path+'Analysis/Aligned/'+name+'_SN2.1.0.ORCS/MAPS/M33-SE_SN2.1.0.LineMaps.map.4861.1x1.flux_align.fits', array2, hdu1.header, clobber=True)
fits.writeto(path+'Analysis/Aligned/'+name+'_SN2.1.0.ORCS/MAPS/M33-SE_SN2.1.0.LineMaps.map.all.1x1.velocity_align.fits', array9, hdu1.header, clobber=True)
fits.writeto(path+'Analysis/Aligned/'+name+'_SN2.1.0.ORCS/MAPS/M33-SE_SN2.1.0.LineMaps.map.4959.1x1.flux_align.fits', array3, hdu1.header, clobber=True)
fits.writeto(path+'Analysis/Aligned/'+name+'_SN2.1.0.ORCS/MAPS/M33-SE_SN2.1.0.LineMaps.map.5007.1x1.flux_align.fits', array4, hdu1.header, clobber=True)
fits.writeto(path+'Analysis/Aligned/'+name+'_SN1.1.0.ORCS/MAPS/M33-SE_SN1.1.0.LineMaps.map.3727.1x1.flux_align.fits', array5, hdu1.header, clobber=True)
fits.writeto(path+'Analysis/Aligned/'+name+'_SN1.1.0.ORCS/MAPS/M33-SE_SN2.1.0.LineMaps.map.all.1x1.height_align.fits', array6, hdu1.header, clobber=True)
fits.writeto(path+'Analysis/Aligned/'+name+'_SN1.1.0.ORCS/MAPS/M33-SE_SN1.1.0.LineMaps.map.all.1x1.height_align.fits', array7, hdu1.header, clobber=True)
fits.writeto(path+'Analysis/Aligned/'+name+'_SN1.1.0.ORCS/MAPS/M33-SE_SN1.1.0.LineMaps.map.all.1x1.velocity_align.fits', array8, hdu1.header, clobber=True)

# Write aligned maps error

fits.writeto(path+'Analysis/Aligned/'+name+'_SN2.1.0.ORCS/MAPS/M33-SE_SN2.1.0.LineMaps.map.4861.1x1.flux-err_align.fits', array22, hdu1.header, clobber=True)
fits.writeto(path+'Analysis/Aligned/'+name+'_SN2.1.0.ORCS/MAPS/M33-SE_SN2.1.0.LineMaps.map.all.1x1.velocity-err_align.fits', array99, hdu1.header, clobber=True)
fits.writeto(path+'Analysis/Aligned/'+name+'_SN2.1.0.ORCS/MAPS/M33-SE_SN2.1.0.LineMaps.map.4959.1x1.flux-err_align.fits', array33, hdu1.header, clobber=True)
fits.writeto(path+'Analysis/Aligned/'+name+'_SN2.1.0.ORCS/MAPS/M33-SE_SN2.1.0.LineMaps.map.5007.1x1.flux-err_align.fits', array44, hdu1.header, clobber=True)
fits.writeto(path+'Analysis/Aligned/'+name+'_SN1.1.0.ORCS/MAPS/M33-SE_SN1.1.0.LineMaps.map.3727.1x1.flux-err_align.fits', array55, hdu1.header, clobber=True)
fits.writeto(path+'Analysis/Aligned/'+name+'_SN1.1.0.ORCS/MAPS/M33-SE_SN2.1.0.LineMaps.map.all.1x1.height-err_align.fits', array66, hdu1.header, clobber=True)
fits.writeto(path+'Analysis/Aligned/'+name+'_SN1.1.0.ORCS/MAPS/M33-SE_SN1.1.0.LineMaps.map.all.1x1.height-err_align.fits', array77, hdu1.header, clobber=True)
fits.writeto(path+'Analysis/Aligned/'+name+'_SN1.1.0.ORCS/MAPS/M33-SE_SN1.1.0.LineMaps.map.all.1x1.velocity-err_align.fits', array88, hdu1.header, clobber=True)
# Out:
# WARNING: AstropyDeprecationWarning: "clobber" was deprecated in version 2.0 and will be removed in a future version. Use argument "overwrite" instead. [astropy.utils.decorators]
# WARNING: AstropyDeprecationWarning: "clobber" was deprecated in version 2.0 and will be removed in a future version. Use argument "overwrite" instead. [astropy.utils.decorators]
# WARNING: AstropyDeprecationWarning: "clobber" was deprecated in version 2.0 and will be removed in a future version. Use argument "overwrite" instead. [astropy.utils.decorators]
# WARNING: AstropyDeprecationWarning: "clobber" was deprecated in version 2.0 and will be removed in a future version. Use argument "overwrite" instead. [astropy.utils.decorators]
# WARNING: AstropyDeprecationWarning: "clobber" was deprecated in version 2.0 and will be removed in a future version. Use argument "overwrite" instead. [astropy.utils.decorators]
# ...
